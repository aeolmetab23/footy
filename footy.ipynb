# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import json
import re

# %%
def getSoup(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    return soup

# %%
TRANSFERMARKT_URL_HEAD = 'https://www.transfermarkt.us'

CURRENCIES = {
    '€': 1,
    '$': 0.89,
    '£': 1.19,
    'm': 1000000,
    'k': 1000
}

# %%
def generateClubs(league_soup):
    clubs = []
    club_link_elements = league_soup.find_all(class_='hauptlink no-border-links')
    
    for club_link_element in club_link_elements:
        club = {}
        club_link = TRANSFERMARKT_URL_HEAD + club_link_element.find('a')['href']
        club_id_pattern = r'/verein/(\d+)/'
        club_id_match = re.search(club_id_pattern, club_link)
        club_id = int(club_id_match.group(1))
        club_name = club_link_element.find('a')['title']
        club['Id'] = club_id
        club['Name'] = club_name
        club['Link'] = club_link
        clubs.append(club)
        
    return clubs

# %%
def generatePlayers(clubs):
    players = []
    
    for club in clubs:
        club_link = club['Link']
        club_soup = getSoup(club_link)
        player_link_elements = club_soup.find_all(lambda tag: tag.has_attr('class') and tag['class'] == ['hauptlink'])
        for player_link_element in player_link_elements:
            player = {}
            player_link = TRANSFERMARKT_URL_HEAD + player_link_element.find('a')['href']
            player_soup = getSoup(player_link)
            player_id_pattern = r'/spieler/(\d+)'
            player_id_match = re.search(player_id_pattern, player_link)
            player_id = int(player_id_match.group(1))
            player_name_element = player_soup.find(class_='data-header__headline-wrapper')
            player_name = player_link_element.text.strip()
            if player_soup.find('span', text='Full name:'):
                player_full_name = player_soup.find('span', text='Full name:').find_next('span').text.strip()
            elif player_soup.find('span', text='Name in home country:'):
                player_full_name = player_soup.find('span', text='Name in home country:').find_next('span').text.strip()
            else:
                player_full_name = player_name
            try:
                player_shirt_number = int(player_soup.find(class_='data-header__shirt-number').text.replace('#', '').strip())
            except:
                player_shirt_number = None
            player_dob_string = player_soup.find('span', text='Date of birth/Age:').find_next('span').text.split('(')[0].strip()
            player_dob = datetime.strptime(player_dob_string, '%b %d, %Y')
            player_country = player_soup.find(itemprop="nationality").text.strip()
            player_position = player_soup.find(class_="detail-position__position").text.strip()
            player_club = club['Name']
            player_contract_expires_string = player_soup.find('span', text='Contract expires:').find_next('span').text.split('(')[0].strip()
            try:
                player_contract_expires = datetime.strptime(player_contract_expires_string, '%b %d, %Y')
            except ValueError:
                player_contract_expires = None
            try:
                player_market_value_pattern = r'([^\d]*)([\d,.]+)([a-zA-Z]+)'
                player_market_value_string = player_soup.find(class_='data-header__market-value-wrapper').text.split(' Last')[0].strip()
                player_market_value_match = re.match(player_market_value_pattern, player_market_value_string).groups()
                player_market_value_currency_conversion = CURRENCIES[player_market_value_match[0]]
                player_market_value_number = float(player_market_value_match[1])
                player_market_value_multiplier = CURRENCIES[player_market_value_match[2]]
                player_market_value = player_market_value_currency_conversion * player_market_value_number * player_market_value_multiplier
            except:
                player_market_value = None
            #print(player_soup.prettify())
            player['Id'] = player_id
            player['Name'] = player_name
            player['Full Name'] = player_full_name
            player['Link'] = player_link
            player['Shirt Number'] = player_shirt_number
            player['DOB'] = player_dob
            player['Country'] = player_country
            player['Position'] = player_position
            player['Club'] = player_club
            player['Contract Expires'] = player_contract_expires
            player['Market Value'] = player_market_value
            players.append(player)
            print(player_club, '-', player_name)
            #break
        #break
    
    return players

# %%
def generateLeague(league_url):
    league = {}
    league_soup = getSoup(league_url)
    league_name = league_soup.find(class_='data-header__headline-wrapper data-header__headline-wrapper--oswald').text.strip()
    league_clubs = generateClubs(league_soup)
    league_players = generatePlayers(league_clubs)
    league['Name'] = league_name
    league['Clubs'] = league_clubs
    league['Players'] = league_players
    
    return league

# %%
PL_URL = 'https://www.transfermarkt.us/premier-league/startseite/wettbewerb/GB1'

league = generateLeague(PL_URL)
# Out:
# Manchester City - Ederson
# Manchester City - Stefan Ortega
# Manchester City - Scott Carson
# Manchester City - Rúben Dias
# Manchester City - Manuel Akanji
# Manchester City - Nathan Aké
# Manchester City - John Stones
# Manchester City - Josko Gvardiol
# Manchester City - Josh Wilson-Esbrand
# Manchester City - Rico Lewis
# Manchester City - Kyle Walker
# Manchester City - Rodri
# Manchester City - Matheus Nunes
# Manchester City - Mateo Kovacic
# Manchester City - İlkay Gündoğan
# Manchester City - James McAtee
# Manchester City - Bernardo Silva
# Manchester City - Kevin De Bruyne
# Manchester City - Jérémy Doku
# Manchester City - Jack Grealish
# Manchester City - Phil Foden
# Manchester City - Savinho
# Manchester City - Oscar Bobb
# Manchester City - Erling Haaland
# Arsenal FC - David Raya
# Arsenal FC - Neto
# Arsenal FC - William Saliba
# Arsenal FC - Gabriel Magalhães
# Arsenal FC - Riccardo Calafiori
# Arsenal FC - Jurrien Timber
# Arsenal FC - Jakub Kiwior
# Arsenal FC - Oleksandr Zinchenko
# Arsenal FC - Kieran Tierney
# Arsenal FC - Ben White
# Arsenal FC - Takehiro Tomiyasu
# Arsenal FC - Declan Rice
# Arsenal FC - Thomas Partey
# Arsenal FC - Jorginho
# Arsenal FC - Mikel Merino
# Arsenal FC - Martin Ødegaard
# Arsenal FC - Gabriel Martinelli
# Arsenal FC - Leandro Trossard
# Arsenal FC - Raheem Sterling
# Arsenal FC - Bukayo Saka
# Arsenal FC - Kai Havertz
# Arsenal FC - Gabriel Jesus
# Chelsea FC - Robert Sánchez
# Chelsea FC - Filip Jørgensen
# Chelsea FC - Marcus Bettinelli
# Chelsea FC - Lucas Bergström
# Chelsea FC - Levi Colwill
# Chelsea FC - Axel Disasi
# Chelsea FC - Benoît Badiashile
# Chelsea FC - Wesley Fofana
# Chelsea FC - Tosin Adarabioyo
# Chelsea FC - Marc Cucurella
# Chelsea FC - Ben Chilwell
# Chelsea FC - Renato Veiga
# Chelsea FC - Reece James
# Chelsea FC - Malo Gusto
# Chelsea FC - Moisés Caicedo
# Chelsea FC - Roméo Lavia
# Chelsea FC - Enzo Fernández
# Chelsea FC - Kiernan Dewsbury-Hall
# Chelsea FC - Carney Chukwuemeka
# Chelsea FC - Cesare Casadei
# Chelsea FC - Cole Palmer
# Chelsea FC - Christopher Nkunku
# Chelsea FC - Mykhaylo Mudryk
# Chelsea FC - João Félix
# Chelsea FC - Jadon Sancho
# Chelsea FC - Pedro Neto
# Chelsea FC - Noni Madueke
# Chelsea FC - Nicolas Jackson
# Chelsea FC - Marc Guiu
# Liverpool FC - Alisson
# Liverpool FC - Caoimhín Kelleher
# Liverpool FC - Vitezslav Jaros
# Liverpool FC - Ibrahima Konaté
# Liverpool FC - Virgil van Dijk
# Liverpool FC - Joe Gomez
# Liverpool FC - Jarell Quansah
# Liverpool FC - Andrew Robertson
# Liverpool FC - Konstantinos Tsimikas
# Liverpool FC - Trent Alexander-Arnold
# Liverpool FC - Conor Bradley
# Liverpool FC - Wataru Endo
# Liverpool FC - Dominik Szoboszlai
# Liverpool FC - Alexis Mac Allister
# Liverpool FC - Curtis Jones
# Liverpool FC - Harvey Elliott
# Liverpool FC - Ryan Gravenberch
# Liverpool FC - Luis Díaz
# Liverpool FC - Cody Gakpo
# Liverpool FC - Federico Chiesa
# Liverpool FC - Mohamed Salah
# Liverpool FC - Darwin Núñez
# Liverpool FC - Diogo Jota
# Manchester United - André Onana
# Manchester United - Altay Bayındır
# Manchester United - Tom Heaton
# Manchester United - Matthijs de Ligt
# Manchester United - Lisandro Martínez
# Manchester United - Leny Yoro
# Manchester United - Harry Maguire
# Manchester United - Victor Lindelöf
# Manchester United - Jonny Evans
# Manchester United - Luke Shaw
# Manchester United - Tyrell Malacia
# Manchester United - Diogo Dalot
# Manchester United - Noussair Mazraoui
# Manchester United - Manuel Ugarte
# Manchester United - Casemiro
# Manchester United - Toby Collyer
# Manchester United - Kobbie Mainoo
# Manchester United - Christian Eriksen
# Manchester United - Daniel Gore
# Manchester United - Bruno Fernandes
# Manchester United - Mason Mount
# Manchester United - Marcus Rashford
# Manchester United - Alejandro Garnacho
# Manchester United - Antony
# Manchester United - Amad Diallo
# Manchester United - Rasmus Højlund
# Manchester United - Joshua Zirkzee
# Tottenham Hotspur - Guglielmo Vicario
# Tottenham Hotspur - Fraser Forster
# Tottenham Hotspur - Brandon Austin
# Tottenham Hotspur - Alfie Whiteman
# Tottenham Hotspur - Cristian Romero
# Tottenham Hotspur - Micky van de Ven
# Tottenham Hotspur - Radu Drăgușin
# Tottenham Hotspur - Ben Davies
# Tottenham Hotspur - Destiny Udogie
# Tottenham Hotspur - Sergio Reguilón
# Tottenham Hotspur - Pedro Porro
# Tottenham Hotspur - Djed Spence
# Tottenham Hotspur - Yves Bissouma
# Tottenham Hotspur - Pape Matar Sarr
# Tottenham Hotspur - Rodrigo Bentancur
# Tottenham Hotspur - Archie Gray
# Tottenham Hotspur - James Maddison
# Tottenham Hotspur - Lucas Bergvall
# Tottenham Hotspur - Heung-min Son
# Tottenham Hotspur - Timo Werner
# Tottenham Hotspur - Wilson Odobert
# Tottenham Hotspur - Dejan Kulusevski
# Tottenham Hotspur - Brennan Johnson
# Tottenham Hotspur - Dominic Solanke
# Tottenham Hotspur - Richarlison
# Newcastle United - Nick Pope
# Newcastle United - Odysseas Vlachodimos
# Newcastle United - Martin Dúbravka
# Newcastle United - Mark Gillespie
# Newcastle United - John Ruddy
# Newcastle United - Sven Botman
# Newcastle United - Lloyd Kelly
# Newcastle United - Fabian Schär
# Newcastle United - Dan Burn
# Newcastle United - Jamaal Lascelles
# Newcastle United - Lewis Hall
# Newcastle United - Matt Targett
# Newcastle United - Alex Murphy
# Newcastle United - Tino Livramento
# Newcastle United - Kieran Trippier
# Newcastle United - Emil Krafth
# Newcastle United - Bruno Guimarães
# Newcastle United - Sandro Tonali
# Newcastle United - Isaac Hayden
# Newcastle United - Joelinton
# Newcastle United - Joe Willock
# Newcastle United - Sean Longstaff
# Newcastle United - Lewis Miley
# Newcastle United - Anthony Gordon
# Newcastle United - Harvey Barnes
# Newcastle United - Garang Kuol
# Newcastle United - Miguel Almirón
# Newcastle United - Jacob Murphy
# Newcastle United - Alexander Isak
# Newcastle United - Callum Wilson
# Newcastle United - William Osula
# Aston Villa - Emiliano Martínez
# Aston Villa - Joe Gauci
# Aston Villa - Robin Olsen
# Aston Villa - Pau Torres
# Aston Villa - Ezri Konsa
# Aston Villa - Diego Carlos
# Aston Villa - Tyrone Mings
# Aston Villa - Kortney Hause
# Aston Villa - Lamare Bogarde
# Aston Villa - Ian Maatsen
# Aston Villa - Lucas Digne
# Aston Villa - Matty Cash
# Aston Villa - Kosta Nedeljkovic
# Aston Villa - Amadou Onana
# Aston Villa - Boubacar Kamara
# Aston Villa - John McGinn
# Aston Villa - Youri Tielemans
# Aston Villa - Ross Barkley
# Aston Villa - Jacob Ramsey
# Aston Villa - Emiliano Buendía
# Aston Villa - Morgan Rogers
# Aston Villa - Jaden Philogene
# Aston Villa - Leon Bailey
# Aston Villa - Ollie Watkins
# Aston Villa - Jhon Durán
# Brighton & Hove Albion - Bart Verbruggen
# Brighton & Hove Albion - Jason Steele
# Brighton & Hove Albion - Adam Webster
# Brighton & Hove Albion - Jan Paul van Hecke
# Brighton & Hove Albion - Igor
# Brighton & Hove Albion - Lewis Dunk
# Brighton & Hove Albion - Ferdi Kadıoğlu
# Brighton & Hove Albion - Pervis Estupiñán
# Brighton & Hove Albion - Imari Samuels
# Brighton & Hove Albion - Jack Hinshelwood
# Brighton & Hove Albion - Tariq Lamptey
# Brighton & Hove Albion - Joël Veltman
# Brighton & Hove Albion - Mats Wieffer
# Brighton & Hove Albion - Carlos Baleba
# Brighton & Hove Albion - Matt O'Riley
# Brighton & Hove Albion - Jakub Moder
# Brighton & Hove Albion - Yasin Ayari
# Brighton & Hove Albion - James Milner
# Brighton & Hove Albion - Julio Enciso
# Brighton & Hove Albion - Kaoru Mitoma
# Brighton & Hove Albion - Simon Adingra
# Brighton & Hove Albion - Brajan Gruda
# Brighton & Hove Albion - Solly March
# Brighton & Hove Albion - Yankuba Minteh
# Brighton & Hove Albion - Evan Ferguson
# Brighton & Hove Albion - João Pedro
# Brighton & Hove Albion - Georginio Rutter
# Brighton & Hove Albion - Danny Welbeck
# West Ham United - Alphonse Areola
# West Ham United - Wes Foderingham
# West Ham United - Lukasz Fabianski
# West Ham United - Jean-Clair Todibo
# West Ham United - Max Kilman
# West Ham United - Konstantinos Mavropanos
# West Ham United - Kaelan Casey
# West Ham United - Emerson
# West Ham United - Aaron Cresswell
# West Ham United - Aaron Wan-Bissaka
# West Ham United - Vladimír Coufal
# West Ham United - Edson Álvarez
# West Ham United - Tomas Soucek
# West Ham United - Guido Rodríguez
# West Ham United - Carlos Soler
# West Ham United - Andy Irving
# West Ham United - Lucas Paquetá
# West Ham United - Mohammed Kudus
# West Ham United - Crysencio Summerville
# West Ham United - Jarrod Bowen
# West Ham United - Luis Guilherme
# West Ham United - Niclas Füllkrug
# West Ham United - Danny Ings
# West Ham United - Michail Antonio
# Crystal Palace - Dean Henderson
# Crystal Palace - Matt Turner
# Crystal Palace - Remi Matthews
# Crystal Palace - Louie Moulden
# Crystal Palace - Marc Guéhi
# Crystal Palace - Maxence Lacroix
# Crystal Palace - Chadi Riad
# Crystal Palace - Trevoh Chalobah
# Crystal Palace - Chris Richards
# Crystal Palace - Rob Holding
# Crystal Palace - Tyrick Mitchell
# Crystal Palace - Daniel Muñoz
# Crystal Palace - Nathaniel Clyne
# Crystal Palace - Joel Ward
# Crystal Palace - Cheick Doucouré
# Crystal Palace - Adam Wharton
# Crystal Palace - Jefferson Lerma
# Crystal Palace - Will Hughes
# Crystal Palace - Jeffrey Schlupp
# Crystal Palace - Eberechi Eze
# Crystal Palace - Daichi Kamada
# Crystal Palace - Matheus França
# Crystal Palace - Ismaïla Sarr
# Crystal Palace - Eddie Nketiah
# Crystal Palace - Jean-Philippe Mateta
# Nottingham Forest - Matz Sels
# Nottingham Forest - Carlos Miguel
# Nottingham Forest - Murillo
# Nottingham Forest - Morato
# Nottingham Forest - Nikola Milenković
# Nottingham Forest - Andrew Omobamidele
# Nottingham Forest - Willy Boly
# Nottingham Forest - Zach Abbott
# Nottingham Forest - Álex Moreno
# Nottingham Forest - Harry Toffolo
# Nottingham Forest - Neco Williams
# Nottingham Forest - Ola Aina
# Nottingham Forest - Ibrahim Sangaré
# Nottingham Forest - Danilo
# Nottingham Forest - James Ward-Prowse
# Nottingham Forest - Nicolás Domínguez
# Nottingham Forest - Elliot Anderson
# Nottingham Forest - Ryan Yates
# Nottingham Forest - Morgan Gibbs-White
# Nottingham Forest - Callum Hudson-Odoi
# Nottingham Forest - Ramón Sosa
# Nottingham Forest - Jota Silva
# Nottingham Forest - Anthony Elanga
# Nottingham Forest - Eric da Silva Moreira
# Nottingham Forest - Taiwo Awoniyi
# Nottingham Forest - Chris Wood
# Nottingham Forest - Emmanuel Dennis
# Brentford FC - Mark Flekken
# Brentford FC - Hákon Rafn Valdimarsson
# Brentford FC - Matthew Cox
# Brentford FC - Nathan Collins
# Brentford FC - Kristoffer Ajer
# Brentford FC - Sepp van den Berg
# Brentford FC - Ethan Pinnock
# Brentford FC - Ben Mee
# Brentford FC - Ji-soo Kim
# Brentford FC - Rico Henry
# Brentford FC - Jayden Meghoma
# Brentford FC - Aaron Hickey
# Brentford FC - Mads Roerslev
# Brentford FC - Vitaly Janelt
# Brentford FC - Christian Nørgaard
# Brentford FC - Yunus Emre Konak
# Brentford FC - Mathias Jensen
# Brentford FC - Josh Dasilva
# Brentford FC - Paris Maghoma
# Brentford FC - Ryan Trevitt
# Brentford FC - Fábio Carvalho
# Brentford FC - Yegor Yarmolyuk
# Brentford FC - Kevin Schade
# Brentford FC - Keane Lewis-Potter
# Brentford FC - Mikkel Damsgaard
# Brentford FC - Gustavo Nunes
# Brentford FC - Bryan Mbeumo
# Brentford FC - Yoane Wissa
# Brentford FC - Igor Thiago
# Wolverhampton Wanderers - José Sá
# Wolverhampton Wanderers - Sam Johnstone
# Wolverhampton Wanderers - Daniel Bentley
# Wolverhampton Wanderers - Tom King
# Wolverhampton Wanderers - Toti
# Wolverhampton Wanderers - Santiago Bueno
# Wolverhampton Wanderers - Yerson Mosquera
# Wolverhampton Wanderers - Craig Dawson
# Wolverhampton Wanderers - Bastien Meupiyou
# Wolverhampton Wanderers - Rayan Aït-Nouri
# Wolverhampton Wanderers - Nélson Semedo
# Wolverhampton Wanderers - Matt Doherty
# Wolverhampton Wanderers - Pedro Lima
# Wolverhampton Wanderers - André
# Wolverhampton Wanderers - Mario Lemina
# Wolverhampton Wanderers - Boubacar Traoré
# Wolverhampton Wanderers - João Gomes
# Wolverhampton Wanderers - Jean-Ricner Bellegarde
# Wolverhampton Wanderers - Tommy Doyle
# Wolverhampton Wanderers - Luke Cundle
# Wolverhampton Wanderers - Rodrigo Gomes
# Wolverhampton Wanderers - Gonçalo Guedes
# Wolverhampton Wanderers - Carlos Forbs
# Wolverhampton Wanderers - Enso González
# Wolverhampton Wanderers - Pablo Sarabia
# Wolverhampton Wanderers - Matheus Cunha
# Wolverhampton Wanderers - Jørgen Strand Larsen
# Wolverhampton Wanderers - Hee-chan Hwang
# Wolverhampton Wanderers - Sasa Kalajdzic
# AFC Bournemouth - Kepa Arrizabalaga
# AFC Bournemouth - Mark Travers
# AFC Bournemouth - Will Dennis
# AFC Bournemouth - Ilya Zabarnyi
# AFC Bournemouth - Marcos Senesi
# AFC Bournemouth - Dean Huijsen
# AFC Bournemouth - James Hill
# AFC Bournemouth - Milos Kerkez
# AFC Bournemouth - Max Aarons
# AFC Bournemouth - Julián Araujo
# AFC Bournemouth - Adam Smith
# AFC Bournemouth - Tyler Adams
# AFC Bournemouth - Philip Billing
# AFC Bournemouth - Alex Scott
# AFC Bournemouth - Lewis Cook
# AFC Bournemouth - Ryan Christie
# AFC Bournemouth - Marcus Tavernier
# AFC Bournemouth - Dango Ouattara
# AFC Bournemouth - Luis Sinisterra
# AFC Bournemouth - Justin Kluivert
# AFC Bournemouth - Antoine Semenyo
# AFC Bournemouth - David Brooks
# AFC Bournemouth - Evanilson
# AFC Bournemouth - Enes Ünal
# Everton FC - Jordan Pickford
# Everton FC - João Virgínia
# Everton FC - Asmir Begovic
# Everton FC - Jarrad Branthwaite
# Everton FC - James Tarkowski
# Everton FC - Jake O'Brien
# Everton FC - Michael Keane
# Everton FC - Vitaliy Mykolenko
# Everton FC - Ashley Young
# Everton FC - Nathan Patterson
# Everton FC - Séamus Coleman
# Everton FC - Roman Dixon
# Everton FC - James Garner
# Everton FC - Orel Mangala
# Everton FC - Abdoulaye Doucouré
# Everton FC - Tim Iroegbunam
# Everton FC - Idrissa Gueye
# Everton FC - Jesper Lindstrøm
# Everton FC - Dwight McNeil
# Everton FC - Jack Harrison
# Everton FC - Dominic Calvert-Lewin
# Everton FC - Armando Broja
# Everton FC - Beto
# Everton FC - Iliman Ndiaye
# Everton FC - Chermiti
# Fulham FC - Bernd Leno
# Fulham FC - Steven Benda
# Fulham FC - Joachim Andersen
# Fulham FC - Issa Diop
# Fulham FC - Calvin Bassey
# Fulham FC - Jorge Cuenca
# Fulham FC - Antonee Robinson
# Fulham FC - Ryan Sessegnon
# Fulham FC - Timothy Castagne
# Fulham FC - Kenny Tete
# Fulham FC - Sander Berge
# Fulham FC - Harrison Reed
# Fulham FC - Saša Lukić
# Fulham FC - Tom Cairney
# Fulham FC - Emile Smith Rowe
# Fulham FC - Andreas Pereira
# Fulham FC - Alex Iwobi
# Fulham FC - Harry Wilson
# Fulham FC - Reiss Nelson
# Fulham FC - Adama Traoré
# Fulham FC - Rodrigo Muniz
# Fulham FC - Raúl Jiménez
# Fulham FC - Carlos Vinícius
# Southampton FC - Aaron Ramsdale
# Southampton FC - Gavin Bazunu
# Southampton FC - Joe Lumley
# Southampton FC - Alex McCarthy
# Southampton FC - Taylor Harwood-Bellis
# Southampton FC - Armel Bella-Kotchap
# Southampton FC - Jan Bednarek
# Southampton FC - Ronnie Edwards
# Southampton FC - Nathan Wood
# Southampton FC - Jack Stephens
# Southampton FC - Juan Larios
# Southampton FC - Ryan Manning
# Southampton FC - Charlie Taylor
# Southampton FC - Kyle Walker-Peters
# Southampton FC - Yukinari Sugawara
# Southampton FC - James Bree
# Southampton FC - Lesley Ugochukwu
# Southampton FC - Flynn Downes
# Southampton FC - Mateus Fernandes
# Southampton FC - Joe Aribo
# Southampton FC - Will Smallbone
# Southampton FC - Adam Lallana
# Southampton FC - Kamaldeen Sulemana
# Southampton FC - Maxwel Cornet
# Southampton FC - Ryan Fraser
# Southampton FC - Samuel Amo-Ameyaw
# Southampton FC - Tyler Dibling
# Southampton FC - Adam Armstrong
# Southampton FC - Cameron Archer
# Southampton FC - Paul Onuachu
# Southampton FC - Ben Brereton Díaz
# Southampton FC - Ross Stewart
# Leicester City - Mads Hermansen
# Leicester City - Daniel Iversen
# Leicester City - Danny Ward
# Leicester City - Jakub Stolarczyk
# Leicester City - Wout Faes
# Leicester City - Caleb Okoli
# Leicester City - Conor Coady
# Leicester City - Jannik Vestergaard
# Leicester City - James Justin
# Leicester City - Victor Kristiansen
# Leicester City - Luke Thomas
# Leicester City - Ricardo Pereira
# Leicester City - Wilfred Ndidi
# Leicester City - Oliver Skipp
# Leicester City - Boubakary Soumaré
# Leicester City - Harry Winks
# Leicester City - Hamza Choudhury
# Leicester City - Michael Golding
# Leicester City - Bilal El Khannouss
# Leicester City - Facundo Buonanotte
# Leicester City - Stephy Mavididi
# Leicester City - Issahaku Fatawu
# Leicester City - Bobby De Cordova-Reid
# Leicester City - Kasey McAteer
# Leicester City - Odsonne Edouard
# Leicester City - Patson Daka
# Leicester City - Jordan Ayew
# Leicester City - Jamie Vardy
# Ipswich Town - Arijanet Muric
# Ipswich Town - Christian Walton
# Ipswich Town - Cieran Slicker
# Ipswich Town - Jacob Greaves
# Ipswich Town - Dara O'Shea
# Ipswich Town - Axel Tuanzebe
# Ipswich Town - Luke Woolfenden
# Ipswich Town - Cameron Burgess
# Ipswich Town - Leif Davis
# Ipswich Town - Conor Townsend
# Ipswich Town - Ben Johnson
# Ipswich Town - Harry Clarke
# Ipswich Town - Kalvin Phillips
# Ipswich Town - Jens Cajuste
# Ipswich Town - Jack Taylor
# Ipswich Town - Sam Morsy
# Ipswich Town - Massimo Luongo
# Ipswich Town - Sammie Szmodics
# Ipswich Town - Jack Clarke
# Ipswich Town - Nathan Broadhead
# Ipswich Town - Chiedozie Ogbene
# Ipswich Town - Omari Hutchinson
# Ipswich Town - Wes Burns
# Ipswich Town - Conor Chaplin
# Ipswich Town - Liam Delap
# Ipswich Town - George Hirst
# Ipswich Town - Ali Al-Hamadi

# %%
league
# Out:
# {'Name': 'Premier League',
#  'Clubs': [{'Id': 281,
#    'Name': 'Manchester City',
#    'Link': 'https://www.transfermarkt.us/manchester-city/startseite/verein/281/saison_id/2024'},
#   {'Id': 11,
#    'Name': 'Arsenal FC',
#    'Link': 'https://www.transfermarkt.us/fc-arsenal/startseite/verein/11/saison_id/2024'},
#   {'Id': 631,
#    'Name': 'Chelsea FC',
#    'Link': 'https://www.transfermarkt.us/fc-chelsea/startseite/verein/631/saison_id/2024'},
#   {'Id': 31,
#    'Name': 'Liverpool FC',
#    'Link': 'https://www.transfermarkt.us/fc-liverpool/startseite/verein/31/saison_id/2024'},
#   {'Id': 985,
#    'Name': 'Manchester United',
#    'Link': 'https://www.transfermarkt.us/manchester-united/startseite/verein/985/saison_id/2024'},
#   {'Id': 148,
#    'Name': 'Tottenham Hotspur',
#    'Link': 'https://www.transfermarkt.us/tottenham-hotspur/startseite/verein/148/saison_id/2024'},
#   {'Id': 762,
#    'Name': 'Newcastle United',
#    'Link': 'https://www.transfermarkt.us/newcastle-united/startseite/verein/762/saison_id/2024'},
#   {'Id': 405,
#    'Name': 'Aston Villa',
#    'Link': 'https://www.transfermarkt.us/aston-villa/startseite/verein/405/saison_id/2024'},
#   {'Id': 1237,
#    'Name': 'Brighton & Hove Albion',
#    'Link': 'https://www.transfermarkt.us/brighton-amp-hove-albion/startseite/verein/1237/saison_id/2024'},
#   {'Id': 379,
#    'Name': 'West Ham United',
#    'Link': 'https://www.transfermarkt.us/west-ham-united/startseite/verein/379/saison_id/2024'},
#   {'Id': 873,
#    'Name': 'Crystal Palace',
#    'Link': 'https://www.transfermarkt.us/crystal-palace/startseite/verein/873/saison_id/2024'},
#   {'Id': 703,
#    'Name': 'Nottingham Forest',
#    'Link': 'https://www.transfermarkt.us/nottingham-forest/startseite/verein/703/saison_id/2024'},
#   {'Id': 1148,
#    'Name': 'Brentford FC',
#    'Link': 'https://www.transfermarkt.us/fc-brentford/startseite/verein/1148/saison_id/2024'},
#   {'Id': 543,
#    'Name': 'Wolverhampton Wanderers',
#    'Link': 'https://www.transfermarkt.us/wolverhampton-wanderers/startseite/verein/543/saison_id/2024'},
#   {'Id': 989,
#    'Name': 'AFC Bournemouth',
#    'Link': 'https://www.transfermarkt.us/afc-bournemouth/startseite/verein/989/saison_id/2024'},
#   {'Id': 29,
#    'Name': 'Everton FC',
#    'Link': 'https://www.transfermarkt.us/fc-everton/startseite/verein/29/saison_id/2024'},
#   {'Id': 931,
#    'Name': 'Fulham FC',
#    'Link': 'https://www.transfermarkt.us/fc-fulham/startseite/verein/931/saison_id/2024'},
#   {'Id': 180,
#    'Name': 'Southampton FC',
#    'Link': 'https://www.transfermarkt.us/fc-southampton/startseite/verein/180/saison_id/2024'},
#   {'Id': 1003,
#    'Name': 'Leicester City',
#    'Link': 'https://www.transfermarkt.us/leicester-city/startseite/verein/1003/saison_id/2024'},
#   {'Id': 677,
#    'Name': 'Ipswich Town',
#    'Link': 'https://www.transfermarkt.us/ipswich-town/startseite/verein/677/saison_id/2024'}],
#  'Players': [{'Id': 238223,
#    'Name': 'Ederson',
#    'Full Name': 'Ederson Santana de Moraes',
#    'Link': 'https://www.transfermarkt.us/ederson/profil/spieler/238223',
#    'Shirt Number': 31,
#    'DOB': '1993-08-17T00:00:00',
#    'Country': 'Brazil',
#    'Position': 'Goalkeeper',
#    'Club': 'Manchester City',
#    'Contract Expires': '2026-06-30T00:00:00',
#    'Market Value': 35000000.0},
#   {'Id': 85941,
#    'Name': 'Stefan Ortega',
#    'Full Name': 'Stefan Ortega Moreno',
#    'Link': 'https://www.transfermarkt.us/stefan-ortega/profil/spieler/85941',
#    'Shirt Number': 18,
#    'DOB': '1992-11-06T00:00:00',
#    'Country': 'Germany',
#    'Position': 'Goalkeeper',
#    'Club': 'Manchester City',
#    'Contract Expires': '2026-06-30T00:00:00',
#    'Market Value': 9000000.0},
#   {'Id': 14555,
#    'Name': 'Scott Carson',
#    'Full Name': 'Scott Paul Carson',
#    'Link': 'https://www.transfermarkt.us/scott-carson/profil/spieler/14555',
#    'Shirt Number': 33,
#    'DOB': '1985-09-03T00:00:00',
#    'Country': 'England',
#    'Position': 'Goalkeeper',
#    'Club': 'Manchester City',
#    'Contract Expires': '2025-06-30T00:00:00',
#    'Market Value': 200000.0},
#   {'Id': 258004,
#    'Name': 'Rúben Dias',
#    'Full Name': 'Rúben Santos Gato Alves Dias',
#    'Link': 'https://www.transfermarkt.us/ruben-dias/profil/spieler/258004',
#    'Shirt Number': 3,
#    'DOB': '1997-05-14T00:00:00',
#    'Country': 'Portugal',
#    'Position': 'Centre-Back',
#    'Club': 'Manchester City',
#    'Contract Expires': '2027-06-30T00:00:00',
#    'Market Value': 80000000.0},
#   {'Id': 284730,
#    'Name': 'Manuel Akanji',
#    'Full Name': 'Manuel Obafemi Akanji',
#    'Link': 'https://www.transfermarkt.us/manuel-akanji/profil/spieler/284730',
#    'Shirt Number': 25,
#    'DOB': '1995-07-19T00:00:00',
#    'Country': 'Switzerland',
#    'Position': 'Centre-Back',
#    'Club': 'Manchester City',
#    'Contract Expires': '2027-06-30T00:00:00',
#    'Market Value': 45000000.0},
#   {'Id': 177476,
#    'Name': 'Nathan Aké',
#    'Full Name': 'Nathan Benjamin Aké',
#    'Link': 'https://www.transfermarkt.us/nathan-ake/profil/spieler/177476',
#    'Shirt Number': 6,
#    'DOB': '1995-02-18T00:00:00',
#    'Country': 'Netherlands',
#    'Position': 'Centre-Back',
#    'Club': 'Manchester City',
#    'Contract Expires': '2027-06-30T00:00:00',
#    'Market Value': 40000000.0},
#   {'Id': 186590,
#    'Name': 'John Stones',
#    'Full Name': 'John Stones',
#    'Link': 'https://www.transfermarkt.us/john-stones/profil/spieler/186590',
#    'Shirt Number': 5,
#    'DOB': '1994-05-28T00:00:00',
#    'Country': 'England',
#    'Position': 'Centre-Back',
#    'Club': 'Manchester City',
#    'Contract Expires': '2026-06-30T00:00:00',
#    'Market Value': 38000000.0},
#   {'Id': 475959,
#    'Name': 'Josko Gvardiol',
#    'Full Name': 'Joško Gvardiol',
#    'Link': 'https://www.transfermarkt.us/josko-gvardiol/profil/spieler/475959',
#    'Shirt Number': 24,
#    'DOB': '2002-01-23T00:00:00',
#    'Country': 'Croatia',
#    'Position': 'Left-Back',
#    'Club': 'Manchester City',
#    'Contract Expires': '2028-06-30T00:00:00',
#    'Market Value': 75000000.0},
#   {'Id': 576121,
#    'Name': 'Josh Wilson-Esbrand',
#    'Full Name': 'Joshua Darius Kamani Wilson-Esbrand',
#    'Link': 'https://www.transfermarkt.us/josh-wilson-esbrand/profil/spieler/576121',
#    'Shirt Number': 97,
#    'DOB': '2002-12-26T00:00:00',
#    'Country': 'England',
#    'Position': 'Left-Back',
#    'Club': 'Manchester City',
#    'Contract Expires': '2027-06-30T00:00:00',
#    'Market Value': 4000000.0},
#   {'Id': 701057,
#    'Name': 'Rico Lewis',
#    'Full Name': 'Rico Henry Mark Lewis',
#    'Link': 'https://www.transfermarkt.us/rico-lewis/profil/spieler/701057',
#    'Shirt Number': 82,
#    'DOB': '2004-11-21T00:00:00',
#    'Country': 'England',
#    'Position': 'Right-Back',
#    'Club': 'Manchester City',
#    'Contract Expires': '2028-06-30T00:00:00',
#    'Market Value': 38000000.0},
#   {'Id': 95424,
#    'Name': 'Kyle Walker',
#    'Full Name': 'Kyle Andrew Walker',
#    'Link': 'https://www.transfermarkt.us/kyle-walker/profil/spieler/95424',
#    'Shirt Number': 2,
#    'DOB': '1990-05-28T00:00:00',
#    'Country': 'England',
#    'Position': 'Right-Back',
#    'Club': 'Manchester City',
#    'Contract Expires': '2026-06-30T00:00:00',
#    'Market Value': 13000000.0},
#   {'Id': 357565,
#    'Name': 'Rodri',
#    'Full Name': 'Rodrigo Hernández Cascante',
#    'Link': 'https://www.transfermarkt.us/rodri/profil/spieler/357565',
#    'Shirt Number': 16,
#    'DOB': '1996-06-22T00:00:00',
#    'Country': 'Spain',
#    'Position': 'Defensive Midfield',
#    'Club': 'Manchester City',
#    'Contract Expires': '2027-06-30T00:00:00',
#    'Market Value': 130000000.0},
#   {'Id': 601883,
#    'Name': 'Matheus Nunes',
#    'Full Name': 'Matheus Luiz Nunes',
#    'Link': 'https://www.transfermarkt.us/matheus-nunes/profil/spieler/601883',
#    'Shirt Number': 27,
#    'DOB': '1998-08-27T00:00:00',
#    'Country': 'Portugal',
#    'Position': 'Central Midfield',
#    'Club': 'Manchester City',
#    'Contract Expires': '2028-06-30T00:00:00',
#    'Market Value': 50000000.0},
#   {'Id': 51471,
#    'Name': 'Mateo Kovacic',
#    'Full Name': 'Mateo Kovačić',
#    'Link': 'https://www.transfermarkt.us/mateo-kovacic/profil/spieler/51471',
#    'Shirt Number': 8,
#    'DOB': '1994-05-06T00:00:00',
#    'Country': 'Croatia',
#    'Position': 'Central Midfield',
#    'Club': 'Manchester City',
#    'Contract Expires': '2027-06-30T00:00:00',
#    'Market Value': 30000000.0},
#   {'Id': 53622,
#    'Name': 'İlkay Gündoğan',
#    'Full Name': 'İlkay Gündoğan',
#    'Link': 'https://www.transfermarkt.us/ilkay-gundogan/profil/spieler/53622',
#    'Shirt Number': 19,
#    'DOB': '1990-10-24T00:00:00',
#    'Country': 'Germany',
#    'Position': 'Central Midfield',
#    'Club': 'Manchester City',
#    'Contract Expires': '2025-06-30T00:00:00',
#    'Market Value': 15000000.0},
#   {'Id': 583199,
#    'Name': 'James McAtee',
#    'Full Name': 'James John McAtee',
#    'Link': 'https://www.transfermarkt.us/james-mcatee/profil/spieler/583199',
#    'Shirt Number': 87,
#    'DOB': '2002-10-18T00:00:00',
#    'Country': 'England',
#    'Position': 'Central Midfield',
#    'Club': 'Manchester City',
#    'Contract Expires': '2026-06-30T00:00:00',
#    'Market Value': 12000000.0},
#   {'Id': 241641,
#    'Name': 'Bernardo Silva',
#    'Full Name': 'Bernardo Mota Veiga de Carvalho e Silva',
#    'Link': 'https://www.transfermarkt.us/bernardo-silva/profil/spieler/241641',
#    'Shirt Number': 20,
#    'DOB': '1994-08-10T00:00:00',
#    'Country': 'Portugal',
#    'Position': 'Attacking Midfield',
#    'Club': 'Manchester City',
#    'Contract Expires': '2026-06-30T00:00:00',
#    'Market Value': 70000000.0},
#   {'Id': 88755,
#    'Name': 'Kevin De Bruyne',
#    'Full Name': 'Kevin De Bruyne',
#    'Link': 'https://www.transfermarkt.us/kevin-de-bruyne/profil/spieler/88755',
#    'Shirt Number': 17,
#    'DOB': '1991-06-28T00:00:00',
#    'Country': 'Belgium',
#    'Position': 'Attacking Midfield',
#    'Club': 'Manchester City',
#    'Contract Expires': '2025-06-30T00:00:00',
#    'Market Value': 50000000.0},
#   {'Id': 486049,
#    'Name': 'Jérémy Doku',
#    'Full Name': 'Jérémy Doku',
#    'Link': 'https://www.transfermarkt.us/jeremy-doku/profil/spieler/486049',
#    'Shirt Number': 11,
#    'DOB': '2002-05-27T00:00:00',
#    'Country': 'Belgium',
#    'Position': 'Left Winger',
#    'Club': 'Manchester City',
#    'Contract Expires': '2028-06-30T00:00:00',
#    'Market Value': 65000000.0},
#   {'Id': 203460,
#    'Name': 'Jack Grealish',
#    'Full Name': 'Jack Peter Grealish',
#    'Link': 'https://www.transfermarkt.us/jack-grealish/profil/spieler/203460',
#    'Shirt Number': 10,
#    'DOB': '1995-09-10T00:00:00',
#    'Country': 'England',
#    'Position': 'Left Winger',
#    'Club': 'Manchester City',
#    'Contract Expires': '2027-06-30T00:00:00',
#    'Market Value': 60000000.0},
#   {'Id': 406635,
#    'Name': 'Phil Foden',
#    'Full Name': 'Philip Walter Foden',
#    'Link': 'https://www.transfermarkt.us/phil-foden/profil/spieler/406635',
#    'Shirt Number': 47,
#    'DOB': '2000-05-28T00:00:00',
#    'Country': 'England',
#    'Position': 'Right Winger',
#    'Club': 'Manchester City',
#    'Contract Expires': '2027-06-30T00:00:00',
#    'Market Value': 150000000.0},
#   {'Id': 743591,
#    'Name': 'Savinho',
#    'Full Name': 'Sávio Moreira de Oliveira',
#    'Link': 'https://www.transfermarkt.us/savinho/profil/spieler/743591',
#    'Shirt Number': 26,
#    'DOB': '2004-04-10T00:00:00',
#    'Country': 'Brazil',
#    'Position': 'Right Winger',
#    'Club': 'Manchester City',
#    'Contract Expires': '2029-06-30T00:00:00',
#    'Market Value': 50000000.0},
#   {'Id': 661207,
#    'Name': 'Oscar Bobb',
#    'Full Name': 'Oscar Bobb',
#    'Link': 'https://www.transfermarkt.us/oscar-bobb/profil/spieler/661207',
#    'Shirt Number': 52,
#    'DOB': '2003-07-12T00:00:00',
#    'Country': 'Norway',
#    'Position': 'Right Winger',
#    'Club': 'Manchester City',
#    'Contract Expires': '2029-06-30T00:00:00',
#    'Market Value': 25000000.0},
#   {'Id': 418560,
#    'Name': 'Erling Haaland',
#    'Full Name': 'Erling Braut Håland',
#    'Link': 'https://www.transfermarkt.us/erling-haaland/profil/spieler/418560',
#    'Shirt Number': 9,
#    'DOB': '2000-07-21T00:00:00',
#    'Country': 'Norway',
#    'Position': 'Centre-Forward',
#    'Club': 'Manchester City',
#    'Contract Expires': '2027-06-30T00:00:00',
#    'Market Value': 180000000.0},
#   {'Id': 262749,
#    'Name': 'David Raya',
#    'Full Name': 'David Raya Martín',
#    'Link': 'https://www.transfermarkt.us/david-raya/profil/spieler/262749',
#    'Shirt Number': 22,
#    'DOB': '1995-09-15T00:00:00',
#    'Country': 'Spain',
#    'Position': 'Goalkeeper',
#    'Club': 'Arsenal FC',
#    'Contract Expires': None,
#    'Market Value': 35000000.0},
#   {'Id': 111819,
#    'Name': 'Neto',
#    'Full Name': 'Norberto Murara Neto',
#    'Link': 'https://www.transfermarkt.us/neto/profil/spieler/111819',
#    'Shirt Number': 32,
#    'DOB': datetime.datetime(1989, 7, 19, 0, 0),
#    'Country': 'Brazil',
#    'Position': 'Goalkeeper',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 2500000.0},
#   {'Id': 495666,
#    'Name': 'William Saliba',
#    'Full Name': 'William Alain André Gabriel Saliba',
#    'Link': 'https://www.transfermarkt.us/william-saliba/profil/spieler/495666',
#    'Shirt Number': 2,
#    'DOB': datetime.datetime(2001, 3, 24, 0, 0),
#    'Country': 'France',
#    'Position': 'Centre-Back',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 80000000.0},
#   {'Id': 435338,
#    'Name': 'Gabriel Magalhães',
#    'Full Name': 'Gabriel dos Santos Magalhães',
#    'Link': 'https://www.transfermarkt.us/gabriel-magalhaes/profil/spieler/435338',
#    'Shirt Number': 6,
#    'DOB': datetime.datetime(1997, 12, 19, 0, 0),
#    'Country': 'Brazil',
#    'Position': 'Centre-Back',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 70000000.0},
#   {'Id': 502821,
#    'Name': 'Riccardo Calafiori',
#    'Full Name': 'Riccardo Calafiori',
#    'Link': 'https://www.transfermarkt.us/riccardo-calafiori/profil/spieler/502821',
#    'Shirt Number': 33,
#    'DOB': datetime.datetime(2002, 5, 19, 0, 0),
#    'Country': 'Italy',
#    'Position': 'Centre-Back',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 45000000.0},
#   {'Id': 420243,
#    'Name': 'Jurrien Timber',
#    'Full Name': 'Jurriën David Norman Timber',
#    'Link': 'https://www.transfermarkt.us/jurrien-timber/profil/spieler/420243',
#    'Shirt Number': 12,
#    'DOB': datetime.datetime(2001, 6, 17, 0, 0),
#    'Country': 'Netherlands',
#    'Position': 'Centre-Back',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 38000000.0},
#   {'Id': 425918,
#    'Name': 'Jakub Kiwior',
#    'Full Name': 'Jakub Piotr Kiwior',
#    'Link': 'https://www.transfermarkt.us/jakub-kiwior/profil/spieler/425918',
#    'Shirt Number': 15,
#    'DOB': datetime.datetime(2000, 2, 15, 0, 0),
#    'Country': 'Poland',
#    'Position': 'Centre-Back',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 30000000.0},
#   {'Id': 203853,
#    'Name': 'Oleksandr Zinchenko',
#    'Full Name': 'Зінченко Олександр Володимирович',
#    'Link': 'https://www.transfermarkt.us/oleksandr-zinchenko/profil/spieler/203853',
#    'Shirt Number': 17,
#    'DOB': datetime.datetime(1996, 12, 15, 0, 0),
#    'Country': 'Ukraine',
#    'Position': 'Left-Back',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 38000000.0},
#   {'Id': 300716,
#    'Name': 'Kieran Tierney',
#    'Full Name': 'Kieran Tierney',
#    'Link': 'https://www.transfermarkt.us/kieran-tierney/profil/spieler/300716',
#    'Shirt Number': 3,
#    'DOB': datetime.datetime(1997, 6, 5, 0, 0),
#    'Country': 'Scotland',
#    'Position': 'Left-Back',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 12000000.0},
#   {'Id': 335721,
#    'Name': 'Ben White',
#    'Full Name': 'Benjamin William White',
#    'Link': 'https://www.transfermarkt.us/ben-white/profil/spieler/335721',
#    'Shirt Number': 4,
#    'DOB': datetime.datetime(1997, 10, 8, 0, 0),
#    'Country': 'England',
#    'Position': 'Right-Back',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 55000000.0},
#   {'Id': 331560,
#    'Name': 'Takehiro Tomiyasu',
#    'Full Name': '冨安 健洋',
#    'Link': 'https://www.transfermarkt.us/takehiro-tomiyasu/profil/spieler/331560',
#    'Shirt Number': 18,
#    'DOB': datetime.datetime(1998, 11, 5, 0, 0),
#    'Country': 'Japan',
#    'Position': 'Right-Back',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 35000000.0},
#   {'Id': 357662,
#    'Name': 'Declan Rice',
#    'Full Name': 'Declan Rice',
#    'Link': 'https://www.transfermarkt.us/declan-rice/profil/spieler/357662',
#    'Shirt Number': 41,
#    'DOB': datetime.datetime(1999, 1, 14, 0, 0),
#    'Country': 'England',
#    'Position': 'Defensive Midfield',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 120000000.0},
#   {'Id': 230784,
#    'Name': 'Thomas Partey',
#    'Full Name': 'Thomas Teye Partey',
#    'Link': 'https://www.transfermarkt.us/thomas-partey/profil/spieler/230784',
#    'Shirt Number': 5,
#    'DOB': datetime.datetime(1993, 6, 13, 0, 0),
#    'Country': 'Ghana',
#    'Position': 'Defensive Midfield',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 18000000.0},
#   {'Id': 102017,
#    'Name': 'Jorginho',
#    'Full Name': 'Jorge Luiz Frello Filho',
#    'Link': 'https://www.transfermarkt.us/jorginho/profil/spieler/102017',
#    'Shirt Number': 20,
#    'DOB': datetime.datetime(1991, 12, 20, 0, 0),
#    'Country': 'Italy',
#    'Position': 'Defensive Midfield',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 12000000.0},
#   {'Id': 338424,
#    'Name': 'Mikel Merino',
#    'Full Name': 'Mikel Merino Zazón',
#    'Link': 'https://www.transfermarkt.us/mikel-merino/profil/spieler/338424',
#    'Shirt Number': 23,
#    'DOB': datetime.datetime(1996, 6, 22, 0, 0),
#    'Country': 'Spain',
#    'Position': 'Central Midfield',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 50000000.0},
#   {'Id': 316264,
#    'Name': 'Martin Ødegaard',
#    'Full Name': 'Martin Ødegaard',
#    'Link': 'https://www.transfermarkt.us/martin-odegaard/profil/spieler/316264',
#    'Shirt Number': 8,
#    'DOB': datetime.datetime(1998, 12, 17, 0, 0),
#    'Country': 'Norway',
#    'Position': 'Attacking Midfield',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 110000000.0},
#   {'Id': 655488,
#    'Name': 'Gabriel Martinelli',
#    'Full Name': 'Gabriel Teodoro Martinelli Silva',
#    'Link': 'https://www.transfermarkt.us/gabriel-martinelli/profil/spieler/655488',
#    'Shirt Number': 11,
#    'DOB': datetime.datetime(2001, 6, 18, 0, 0),
#    'Country': 'Brazil',
#    'Position': 'Left Winger',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 70000000.0},
#   {'Id': 144028,
#    'Name': 'Leandro Trossard',
#    'Full Name': 'Leandro Trossard',
#    'Link': 'https://www.transfermarkt.us/leandro-trossard/profil/spieler/144028',
#    'Shirt Number': 19,
#    'DOB': datetime.datetime(1994, 12, 4, 0, 0),
#    'Country': 'Belgium',
#    'Position': 'Left Winger',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 35000000.0},
#   {'Id': 134425,
#    'Name': 'Raheem Sterling',
#    'Full Name': 'Raheem Shaquille Sterling',
#    'Link': 'https://www.transfermarkt.us/raheem-sterling/profil/spieler/134425',
#    'Shirt Number': 30,
#    'DOB': datetime.datetime(1994, 12, 8, 0, 0),
#    'Country': 'England',
#    'Position': 'Left Winger',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2025, 5, 31, 0, 0),
#    'Market Value': 35000000.0},
#   {'Id': 433177,
#    'Name': 'Bukayo Saka',
#    'Full Name': 'Bukayo Saka',
#    'Link': 'https://www.transfermarkt.us/bukayo-saka/profil/spieler/433177',
#    'Shirt Number': 7,
#    'DOB': datetime.datetime(2001, 9, 5, 0, 0),
#    'Country': 'England',
#    'Position': 'Right Winger',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 140000000.0},
#   {'Id': 309400,
#    'Name': 'Kai Havertz',
#    'Full Name': 'Kai Lukas Havertz',
#    'Link': 'https://www.transfermarkt.us/kai-havertz/profil/spieler/309400',
#    'Shirt Number': 29,
#    'DOB': datetime.datetime(1999, 6, 11, 0, 0),
#    'Country': 'Germany',
#    'Position': 'Centre-Forward',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 70000000.0},
#   {'Id': 363205,
#    'Name': 'Gabriel Jesus',
#    'Full Name': 'Gabriel Jesus',
#    'Link': 'https://www.transfermarkt.us/gabriel-jesus/profil/spieler/363205',
#    'Shirt Number': 9,
#    'DOB': datetime.datetime(1997, 4, 3, 0, 0),
#    'Country': 'Brazil',
#    'Position': 'Centre-Forward',
#    'Club': 'Arsenal FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 65000000.0},
#   {'Id': 403151,
#    'Name': 'Robert Sánchez',
#    'Full Name': 'Robert Sánchez',
#    'Link': 'https://www.transfermarkt.us/robert-sanchez/profil/spieler/403151',
#    'Shirt Number': 1,
#    'DOB': datetime.datetime(1997, 11, 18, 0, 0),
#    'Country': 'Spain',
#    'Position': 'Goalkeeper',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2030, 6, 30, 0, 0),
#    'Market Value': 20000000.0},
#   {'Id': 585323,
#    'Name': 'Filip Jørgensen',
#    'Full Name': 'Filip Jørgensen',
#    'Link': 'https://www.transfermarkt.us/filip-jorgensen/profil/spieler/585323',
#    'Shirt Number': 12,
#    'DOB': datetime.datetime(2002, 4, 16, 0, 0),
#    'Country': 'Denmark',
#    'Position': 'Goalkeeper',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2031, 6, 30, 0, 0),
#    'Market Value': 20000000.0},
#   {'Id': 116648,
#    'Name': 'Marcus Bettinelli',
#    'Full Name': 'Marcus Bettinelli',
#    'Link': 'https://www.transfermarkt.us/marcus-bettinelli/profil/spieler/116648',
#    'Shirt Number': 13,
#    'DOB': datetime.datetime(1992, 5, 24, 0, 0),
#    'Country': 'England',
#    'Position': 'Goalkeeper',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 1000000.0},
#   {'Id': 490606,
#    'Name': 'Lucas Bergström',
#    'Full Name': 'Lucas Carl Edvard Bergström',
#    'Link': 'https://www.transfermarkt.us/lucas-bergstrom/profil/spieler/490606',
#    'Shirt Number': 47,
#    'DOB': datetime.datetime(2002, 9, 5, 0, 0),
#    'Country': 'Finland',
#    'Position': 'Goalkeeper',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 700000.0},
#   {'Id': 614258,
#    'Name': 'Levi Colwill',
#    'Full Name': 'Levi Lemar Samuel Colwill',
#    'Link': 'https://www.transfermarkt.us/levi-colwill/profil/spieler/614258',
#    'Shirt Number': 6,
#    'DOB': datetime.datetime(2003, 2, 26, 0, 0),
#    'Country': 'England',
#    'Position': 'Centre-Back',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 50000000.0},
#   {'Id': 386047,
#    'Name': 'Axel Disasi',
#    'Full Name': 'Axel Disasi',
#    'Link': 'https://www.transfermarkt.us/axel-disasi/profil/spieler/386047',
#    'Shirt Number': 2,
#    'DOB': datetime.datetime(1998, 3, 11, 0, 0),
#    'Country': 'France',
#    'Position': 'Centre-Back',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 40000000.0},
#   {'Id': 463603,
#    'Name': 'Benoît Badiashile',
#    'Full Name': 'Benoît Badiashile Mukinayi',
#    'Link': 'https://www.transfermarkt.us/benoit-badiashile/profil/spieler/463603',
#    'Shirt Number': 5,
#    'DOB': datetime.datetime(2001, 3, 26, 0, 0),
#    'Country': 'France',
#    'Position': 'Centre-Back',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2030, 6, 30, 0, 0),
#    'Market Value': 30000000.0},
#   {'Id': 475411,
#    'Name': 'Wesley Fofana',
#    'Full Name': 'Wesley Fofana',
#    'Link': 'https://www.transfermarkt.us/wesley-fofana/profil/spieler/475411',
#    'Shirt Number': 29,
#    'DOB': datetime.datetime(2000, 12, 17, 0, 0),
#    'Country': 'France',
#    'Position': 'Centre-Back',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 25000000.0},
#   {'Id': 258878,
#    'Name': 'Tosin Adarabioyo',
#    'Full Name': 'Abdul-Nasir Oluwatosin Oluwadoyinsolami Adarabioyo',
#    'Link': 'https://www.transfermarkt.us/tosin-adarabioyo/profil/spieler/258878',
#    'Shirt Number': 4,
#    'DOB': datetime.datetime(1997, 9, 24, 0, 0),
#    'Country': 'England',
#    'Position': 'Centre-Back',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 20000000.0},
#   {'Id': 284857,
#    'Name': 'Marc Cucurella',
#    'Full Name': 'Marc Cucurella Saseta',
#    'Link': 'https://www.transfermarkt.us/marc-cucurella/profil/spieler/284857',
#    'Shirt Number': 3,
#    'DOB': datetime.datetime(1998, 7, 22, 0, 0),
#    'Country': 'Spain',
#    'Position': 'Left-Back',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 30000000.0},
#   {'Id': 316125,
#    'Name': 'Ben Chilwell',
#    'Full Name': 'Benjamin James Chilwell',
#    'Link': 'https://www.transfermarkt.us/ben-chilwell/profil/spieler/316125',
#    'Shirt Number': 21,
#    'DOB': datetime.datetime(1996, 12, 21, 0, 0),
#    'Country': 'England',
#    'Position': 'Left-Back',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 28000000.0},
#   {'Id': 805714,
#    'Name': 'Renato Veiga',
#    'Full Name': 'Renato Palma Veiga',
#    'Link': 'https://www.transfermarkt.us/renato-veiga/profil/spieler/805714',
#    'Shirt Number': 40,
#    'DOB': datetime.datetime(2003, 7, 29, 0, 0),
#    'Country': 'Portugal',
#    'Position': 'Left-Back',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2031, 6, 30, 0, 0),
#    'Market Value': 3000000.0},
#   {'Id': 472423,
#    'Name': 'Reece James',
#    'Full Name': 'Reece James',
#    'Link': 'https://www.transfermarkt.us/reece-james/profil/spieler/472423',
#    'Shirt Number': 24,
#    'DOB': datetime.datetime(1999, 12, 8, 0, 0),
#    'Country': 'England',
#    'Position': 'Right-Back',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 40000000.0},
#   {'Id': 620322,
#    'Name': 'Malo Gusto',
#    'Full Name': 'Malo Gusto',
#    'Link': 'https://www.transfermarkt.us/malo-gusto/profil/spieler/620322',
#    'Shirt Number': 27,
#    'DOB': datetime.datetime(2003, 5, 19, 0, 0),
#    'Country': 'France',
#    'Position': 'Right-Back',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2030, 6, 30, 0, 0),
#    'Market Value': 35000000.0},
#   {'Id': 687626,
#    'Name': 'Moisés Caicedo',
#    'Full Name': 'Moisés Isaac Caicedo Corozo',
#    'Link': 'https://www.transfermarkt.us/moises-caicedo/profil/spieler/687626',
#    'Shirt Number': 25,
#    'DOB': datetime.datetime(2001, 11, 2, 0, 0),
#    'Country': 'Ecuador',
#    'Position': 'Defensive Midfield',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2031, 6, 30, 0, 0),
#    'Market Value': 75000000.0},
#   {'Id': 628451,
#    'Name': 'Roméo Lavia',
#    'Full Name': 'Roméo Lavia',
#    'Link': 'https://www.transfermarkt.us/romeo-lavia/profil/spieler/628451',
#    'Shirt Number': 45,
#    'DOB': datetime.datetime(2004, 1, 6, 0, 0),
#    'Country': 'Belgium',
#    'Position': 'Defensive Midfield',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2030, 6, 30, 0, 0),
#    'Market Value': 35000000.0},
#   {'Id': 648195,
#    'Name': 'Enzo Fernández',
#    'Full Name': 'Enzo Jeremías Fernández',
#    'Link': 'https://www.transfermarkt.us/enzo-fernandez/profil/spieler/648195',
#    'Shirt Number': 8,
#    'DOB': datetime.datetime(2001, 1, 17, 0, 0),
#    'Country': 'Argentina',
#    'Position': 'Central Midfield',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2032, 6, 30, 0, 0),
#    'Market Value': 75000000.0},
#   {'Id': 475188,
#    'Name': 'Kiernan Dewsbury-Hall',
#    'Full Name': 'Kiernan Frank Dewsbury-Hall',
#    'Link': 'https://www.transfermarkt.us/kiernan-dewsbury-hall/profil/spieler/475188',
#    'Shirt Number': 22,
#    'DOB': datetime.datetime(1998, 9, 6, 0, 0),
#    'Country': 'England',
#    'Position': 'Central Midfield',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 30000000.0},
#   {'Id': 659459,
#    'Name': 'Carney Chukwuemeka',
#    'Full Name': 'Carney Chibueze Chukwuemeka',
#    'Link': 'https://www.transfermarkt.us/carney-chukwuemeka/profil/spieler/659459',
#    'Shirt Number': 17,
#    'DOB': datetime.datetime(2003, 10, 20, 0, 0),
#    'Country': 'England',
#    'Position': 'Central Midfield',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 15000000.0},
#   {'Id': 622380,
#    'Name': 'Cesare Casadei',
#    'Full Name': 'Cesare Casadei',
#    'Link': 'https://www.transfermarkt.us/cesare-casadei/profil/spieler/622380',
#    'Shirt Number': 31,
#    'DOB': datetime.datetime(2003, 1, 10, 0, 0),
#    'Country': 'Italy',
#    'Position': 'Central Midfield',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 10000000.0},
#   {'Id': 568177,
#    'Name': 'Cole Palmer',
#    'Full Name': 'Cole Jermaine Palmer',
#    'Link': 'https://www.transfermarkt.us/cole-palmer/profil/spieler/568177',
#    'Shirt Number': 20,
#    'DOB': datetime.datetime(2002, 5, 6, 0, 0),
#    'Country': 'England',
#    'Position': 'Attacking Midfield',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2033, 6, 30, 0, 0),
#    'Market Value': 80000000.0},
#   {'Id': 344381,
#    'Name': 'Christopher Nkunku',
#    'Full Name': 'Christopher Alan Nkunku',
#    'Link': 'https://www.transfermarkt.us/christopher-nkunku/profil/spieler/344381',
#    'Shirt Number': 18,
#    'DOB': datetime.datetime(1997, 11, 14, 0, 0),
#    'Country': 'France',
#    'Position': 'Attacking Midfield',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 65000000.0},
#   {'Id': 537860,
#    'Name': 'Mykhaylo Mudryk',
#    'Full Name': 'Мудрик Михайло Петрович',
#    'Link': 'https://www.transfermarkt.us/mykhaylo-mudryk/profil/spieler/537860',
#    'Shirt Number': 10,
#    'DOB': datetime.datetime(2001, 1, 5, 0, 0),
#    'Country': 'Ukraine',
#    'Position': 'Left Winger',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2031, 6, 30, 0, 0),
#    'Market Value': 35000000.0},
#   {'Id': 462250,
#    'Name': 'João Félix',
#    'Full Name': 'João Félix Sequeira',
#    'Link': 'https://www.transfermarkt.us/joao-felix/profil/spieler/462250',
#    'Shirt Number': 14,
#    'DOB': datetime.datetime(1999, 11, 10, 0, 0),
#    'Country': 'Portugal',
#    'Position': 'Left Winger',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2031, 6, 30, 0, 0),
#    'Market Value': 30000000.0},
#   {'Id': 401173,
#    'Name': 'Jadon Sancho',
#    'Full Name': 'Jadon Malik Sancho',
#    'Link': 'https://www.transfermarkt.us/jadon-sancho/profil/spieler/401173',
#    'Shirt Number': 19,
#    'DOB': datetime.datetime(2000, 3, 25, 0, 0),
#    'Country': 'England',
#    'Position': 'Left Winger',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 30000000.0},
#   {'Id': 487465,
#    'Name': 'Pedro Neto',
#    'Full Name': 'Pedro Lomba Neto',
#    'Link': 'https://www.transfermarkt.us/pedro-neto/profil/spieler/487465',
#    'Shirt Number': 7,
#    'DOB': datetime.datetime(2000, 3, 9, 0, 0),
#    'Country': 'Portugal',
#    'Position': 'Right Winger',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2031, 6, 30, 0, 0),
#    'Market Value': 55000000.0},
#   {'Id': 503987,
#    'Name': 'Noni Madueke',
#    'Full Name': 'Chukwunonso Tristan Madueke',
#    'Link': 'https://www.transfermarkt.us/noni-madueke/profil/spieler/503987',
#    'Shirt Number': 11,
#    'DOB': datetime.datetime(2002, 3, 10, 0, 0),
#    'Country': 'England',
#    'Position': 'Right Winger',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2030, 6, 30, 0, 0),
#    'Market Value': 28000000.0},
#   {'Id': 776890,
#    'Name': 'Nicolas Jackson',
#    'Full Name': 'Nicolas Jackson',
#    'Link': 'https://www.transfermarkt.us/nicolas-jackson/profil/spieler/776890',
#    'Shirt Number': 15,
#    'DOB': datetime.datetime(2001, 6, 20, 0, 0),
#    'Country': 'Senegal',
#    'Position': 'Centre-Forward',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2033, 6, 30, 0, 0),
#    'Market Value': 35000000.0},
#   {'Id': 938158,
#    'Name': 'Marc Guiu',
#    'Full Name': 'Marc Guiu Paz',
#    'Link': 'https://www.transfermarkt.us/marc-guiu/profil/spieler/938158',
#    'Shirt Number': 38,
#    'DOB': datetime.datetime(2006, 1, 4, 0, 0),
#    'Country': 'Spain',
#    'Position': 'Centre-Forward',
#    'Club': 'Chelsea FC',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 7500000.0},
#   {'Id': 105470,
#    'Name': 'Alisson',
#    'Full Name': 'Alisson Ramses Becker',
#    'Link': 'https://www.transfermarkt.us/alisson/profil/spieler/105470',
#    'Shirt Number': 1,
#    'DOB': datetime.datetime(1992, 10, 2, 0, 0),
#    'Country': 'Brazil',
#    'Position': 'Goalkeeper',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 28000000.0},
#   {'Id': 340918,
#    'Name': 'Caoimhín Kelleher',
#    'Full Name': 'Caoimhín Odhrán Kelleher',
#    'Link': 'https://www.transfermarkt.us/caoimhin-kelleher/profil/spieler/340918',
#    'Shirt Number': 62,
#    'DOB': datetime.datetime(1998, 11, 23, 0, 0),
#    'Country': 'Ireland',
#    'Position': 'Goalkeeper',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 20000000.0},
#   {'Id': 486604,
#    'Name': 'Vitezslav Jaros',
#    'Full Name': 'Vítězslav Jaroš',
#    'Link': 'https://www.transfermarkt.us/vitezslav-jaros/profil/spieler/486604',
#    'Shirt Number': 56,
#    'DOB': datetime.datetime(2001, 7, 23, 0, 0),
#    'Country': 'Czech Republic',
#    'Position': 'Goalkeeper',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 5000000.0},
#   {'Id': 357119,
#    'Name': 'Ibrahima Konaté',
#    'Full Name': 'Ibrahima Konaté',
#    'Link': 'https://www.transfermarkt.us/ibrahima-konate/profil/spieler/357119',
#    'Shirt Number': 5,
#    'DOB': datetime.datetime(1999, 5, 25, 0, 0),
#    'Country': 'France',
#    'Position': 'Centre-Back',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 45000000.0},
#   {'Id': 139208,
#    'Name': 'Virgil van Dijk',
#    'Full Name': 'Virgil van Dijk',
#    'Link': 'https://www.transfermarkt.us/virgil-van-dijk/profil/spieler/139208',
#    'Shirt Number': 4,
#    'DOB': datetime.datetime(1991, 7, 8, 0, 0),
#    'Country': 'Netherlands',
#    'Position': 'Centre-Back',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 30000000.0},
#   {'Id': 256178,
#    'Name': 'Joe Gomez',
#    'Full Name': 'Joseph Dave Gomez',
#    'Link': 'https://www.transfermarkt.us/joe-gomez/profil/spieler/256178',
#    'Shirt Number': 2,
#    'DOB': datetime.datetime(1997, 5, 23, 0, 0),
#    'Country': 'England',
#    'Position': 'Centre-Back',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 28000000.0},
#   {'Id': 632349,
#    'Name': 'Jarell Quansah',
#    'Full Name': 'Jarell Amorin Quansah',
#    'Link': 'https://www.transfermarkt.us/jarell-quansah/profil/spieler/632349',
#    'Shirt Number': 78,
#    'DOB': datetime.datetime(2003, 1, 29, 0, 0),
#    'Country': 'England',
#    'Position': 'Centre-Back',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 22000000.0},
#   {'Id': 234803,
#    'Name': 'Andrew Robertson',
#    'Full Name': 'Andrew Henry Robertson',
#    'Link': 'https://www.transfermarkt.us/andrew-robertson/profil/spieler/234803',
#    'Shirt Number': 26,
#    'DOB': datetime.datetime(1994, 3, 11, 0, 0),
#    'Country': 'Scotland',
#    'Position': 'Left-Back',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 30000000.0},
#   {'Id': 338070,
#    'Name': 'Konstantinos Tsimikas',
#    'Full Name': 'Κωνσταντίνος Τσιμίκας',
#    'Link': 'https://www.transfermarkt.us/konstantinos-tsimikas/profil/spieler/338070',
#    'Shirt Number': 21,
#    'DOB': datetime.datetime(1996, 5, 12, 0, 0),
#    'Country': 'Greece',
#    'Position': 'Left-Back',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 22000000.0},
#   {'Id': 314353,
#    'Name': 'Trent Alexander-Arnold',
#    'Full Name': 'Trent John Alexander-Arnold',
#    'Link': 'https://www.transfermarkt.us/trent-alexander-arnold/profil/spieler/314353',
#    'Shirt Number': 66,
#    'DOB': datetime.datetime(1998, 10, 7, 0, 0),
#    'Country': 'England',
#    'Position': 'Right-Back',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 70000000.0},
#   {'Id': 624258,
#    'Name': 'Conor Bradley',
#    'Full Name': 'Conor Bradley',
#    'Link': 'https://www.transfermarkt.us/conor-bradley/profil/spieler/624258',
#    'Shirt Number': 84,
#    'DOB': datetime.datetime(2003, 7, 9, 0, 0),
#    'Country': 'Northern Ireland',
#    'Position': 'Right-Back',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 15000000.0},
#   {'Id': 146310,
#    'Name': 'Wataru Endo',
#    'Full Name': '遠藤 航',
#    'Link': 'https://www.transfermarkt.us/wataru-endo/profil/spieler/146310',
#    'Shirt Number': 3,
#    'DOB': datetime.datetime(1993, 2, 9, 0, 0),
#    'Country': 'Japan',
#    'Position': 'Defensive Midfield',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 13000000.0},
#   {'Id': 451276,
#    'Name': 'Dominik Szoboszlai',
#    'Full Name': 'Dominik Szoboszlai',
#    'Link': 'https://www.transfermarkt.us/dominik-szoboszlai/profil/spieler/451276',
#    'Shirt Number': 8,
#    'DOB': datetime.datetime(2000, 10, 25, 0, 0),
#    'Country': 'Hungary',
#    'Position': 'Central Midfield',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 75000000.0},
#   {'Id': 534033,
#    'Name': 'Alexis Mac Allister',
#    'Full Name': 'Alexis Mac Allister',
#    'Link': 'https://www.transfermarkt.us/alexis-mac-allister/profil/spieler/534033',
#    'Shirt Number': 10,
#    'DOB': datetime.datetime(1998, 12, 24, 0, 0),
#    'Country': 'Argentina',
#    'Position': 'Central Midfield',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 75000000.0},
#   {'Id': 433188,
#    'Name': 'Curtis Jones',
#    'Full Name': 'Curtis Jones',
#    'Link': 'https://www.transfermarkt.us/curtis-jones/profil/spieler/433188',
#    'Shirt Number': 17,
#    'DOB': datetime.datetime(2001, 1, 30, 0, 0),
#    'Country': 'England',
#    'Position': 'Central Midfield',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 35000000.0},
#   {'Id': 565822,
#    'Name': 'Harvey Elliott',
#    'Full Name': 'Harvey Scott Elliott',
#    'Link': 'https://www.transfermarkt.us/harvey-elliott/profil/spieler/565822',
#    'Shirt Number': 19,
#    'DOB': datetime.datetime(2003, 4, 4, 0, 0),
#    'Country': 'England',
#    'Position': 'Central Midfield',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 35000000.0},
#   {'Id': 478573,
#    'Name': 'Ryan Gravenberch',
#    'Full Name': 'Ryan Jiro Gravenberch',
#    'Link': 'https://www.transfermarkt.us/ryan-gravenberch/profil/spieler/478573',
#    'Shirt Number': 38,
#    'DOB': datetime.datetime(2002, 5, 16, 0, 0),
#    'Country': 'Netherlands',
#    'Position': 'Central Midfield',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 35000000.0},
#   {'Id': 480692,
#    'Name': 'Luis Díaz',
#    'Full Name': 'Luis Fernando Díaz Marulanda',
#    'Link': 'https://www.transfermarkt.us/luis-diaz/profil/spieler/480692',
#    'Shirt Number': 7,
#    'DOB': datetime.datetime(1997, 1, 13, 0, 0),
#    'Country': 'Colombia',
#    'Position': 'Left Winger',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 75000000.0},
#   {'Id': 434675,
#    'Name': 'Cody Gakpo',
#    'Full Name': 'Cody Mathès Gakpo',
#    'Link': 'https://www.transfermarkt.us/cody-gakpo/profil/spieler/434675',
#    'Shirt Number': 18,
#    'DOB': datetime.datetime(1999, 5, 7, 0, 0),
#    'Country': 'Netherlands',
#    'Position': 'Left Winger',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 55000000.0},
#   {'Id': 341092,
#    'Name': 'Federico Chiesa',
#    'Full Name': 'Federico Chiesa',
#    'Link': 'https://www.transfermarkt.us/federico-chiesa/profil/spieler/341092',
#    'Shirt Number': 14,
#    'DOB': datetime.datetime(1997, 10, 25, 0, 0),
#    'Country': 'Italy',
#    'Position': 'Left Winger',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 35000000.0},
#   {'Id': 148455,
#    'Name': 'Mohamed Salah',
#    'Full Name': 'Mohamed Salah Hamed Ghaly',
#    'Link': 'https://www.transfermarkt.us/mohamed-salah/profil/spieler/148455',
#    'Shirt Number': 11,
#    'DOB': datetime.datetime(1992, 6, 15, 0, 0),
#    'Country': 'Egypt',
#    'Position': 'Right Winger',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 55000000.0},
#   {'Id': 546543,
#    'Name': 'Darwin Núñez',
#    'Full Name': 'Darwin Gabriel Núñez Ribeiro',
#    'Link': 'https://www.transfermarkt.us/darwin-nunez/profil/spieler/546543',
#    'Shirt Number': 9,
#    'DOB': datetime.datetime(1999, 6, 24, 0, 0),
#    'Country': 'Uruguay',
#    'Position': 'Centre-Forward',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 70000000.0},
#   {'Id': 340950,
#    'Name': 'Diogo Jota',
#    'Full Name': 'Diogo José Teixeira da Silva',
#    'Link': 'https://www.transfermarkt.us/diogo-jota/profil/spieler/340950',
#    'Shirt Number': 20,
#    'DOB': datetime.datetime(1996, 12, 4, 0, 0),
#    'Country': 'Portugal',
#    'Position': 'Centre-Forward',
#    'Club': 'Liverpool FC',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 50000000.0},
#   {'Id': 234509,
#    'Name': 'André Onana',
#    'Full Name': 'André Onana',
#    'Link': 'https://www.transfermarkt.us/andre-onana/profil/spieler/234509',
#    'Shirt Number': 24,
#    'DOB': datetime.datetime(1996, 4, 2, 0, 0),
#    'Country': 'Cameroon',
#    'Position': 'Goalkeeper',
#    'Club': 'Manchester United',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 35000000.0},
#   {'Id': 336077,
#    'Name': 'Altay Bayındır',
#    'Full Name': 'Altay Bayındır',
#    'Link': 'https://www.transfermarkt.us/altay-bayindir/profil/spieler/336077',
#    'Shirt Number': 1,
#    'DOB': datetime.datetime(1998, 4, 14, 0, 0),
#    'Country': 'Türkiye',
#    'Position': 'Goalkeeper',
#    'Club': 'Manchester United',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 10000000.0},
#   {'Id': 34130,
#    'Name': 'Tom Heaton',
#    'Full Name': 'Thomas David Heaton',
#    'Link': 'https://www.transfermarkt.us/tom-heaton/profil/spieler/34130',
#    'Shirt Number': 22,
#    'DOB': datetime.datetime(1986, 4, 15, 0, 0),
#    'Country': 'England',
#    'Position': 'Goalkeeper',
#    'Club': 'Manchester United',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 250000.0},
#   {'Id': 326031,
#    'Name': 'Matthijs de Ligt',
#    'Full Name': 'Matthijs de Ligt',
#    'Link': 'https://www.transfermarkt.us/matthijs-de-ligt/profil/spieler/326031',
#    'Shirt Number': 4,
#    'DOB': datetime.datetime(1999, 8, 12, 0, 0),
#    'Country': 'Netherlands',
#    'Position': 'Centre-Back',
#    'Club': 'Manchester United',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 65000000.0},
#   {'Id': 480762,
#    'Name': 'Lisandro Martínez',
#    'Full Name': 'Lisandro Martínez',
#    'Link': 'https://www.transfermarkt.us/lisandro-martinez/profil/spieler/480762',
#    'Shirt Number': 6,
#    'DOB': datetime.datetime(1998, 1, 18, 0, 0),
#    'Country': 'Argentina',
#    'Position': 'Centre-Back',
#    'Club': 'Manchester United',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 50000000.0},
#   {'Id': 923831,
#    'Name': 'Leny Yoro',
#    'Full Name': 'Leny Yoro',
#    'Link': 'https://www.transfermarkt.us/leny-yoro/profil/spieler/923831',
#    'Shirt Number': 15,
#    'DOB': datetime.datetime(2005, 11, 13, 0, 0),
#    'Country': 'France',
#    'Position': 'Centre-Back',
#    'Club': 'Manchester United',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 50000000.0},
#   {'Id': 177907,
#    'Name': 'Harry Maguire',
#    'Full Name': 'Jacob Harry Maguire',
#    'Link': 'https://www.transfermarkt.us/harry-maguire/profil/spieler/177907',
#    'Shirt Number': 5,
#    'DOB': datetime.datetime(1993, 3, 5, 0, 0),
#    'Country': 'England',
#    'Position': 'Centre-Back',
#    'Club': 'Manchester United',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 18000000.0},
#   {'Id': 184573,
#    'Name': 'Victor Lindelöf',
#    'Full Name': 'Victor Jörgen Nilsson-Lindelöf',
#    'Link': 'https://www.transfermarkt.us/victor-lindelof/profil/spieler/184573',
#    'Shirt Number': 2,
#    'DOB': datetime.datetime(1994, 7, 17, 0, 0),
#    'Country': 'Sweden',
#    'Position': 'Centre-Back',
#    'Club': 'Manchester United',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 15000000.0},
#   {'Id': 42412,
#    'Name': 'Jonny Evans',
#    'Full Name': 'Jonathan Grant Evans',
#    'Link': 'https://www.transfermarkt.us/jonny-evans/profil/spieler/42412',
#    'Shirt Number': 35,
#    'DOB': datetime.datetime(1988, 1, 3, 0, 0),
#    'Country': 'Northern Ireland',
#    'Position': 'Centre-Back',
#    'Club': 'Manchester United',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 2000000.0},
#   {'Id': 183288,
#    'Name': 'Luke Shaw',
#    'Full Name': 'Luke Paul Hoare Shaw',
#    'Link': 'https://www.transfermarkt.us/luke-shaw/profil/spieler/183288',
#    'Shirt Number': 23,
#    'DOB': datetime.datetime(1995, 7, 12, 0, 0),
#    'Country': 'England',
#    'Position': 'Left-Back',
#    'Club': 'Manchester United',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 32000000.0},
#   {'Id': 339340,
#    'Name': 'Tyrell Malacia',
#    'Full Name': 'Tyrell Johannes Chicco Malacia',
#    'Link': 'https://www.transfermarkt.us/tyrell-malacia/profil/spieler/339340',
#    'Shirt Number': 12,
#    'DOB': datetime.datetime(1999, 8, 17, 0, 0),
#    'Country': 'Netherlands',
#    'Position': 'Left-Back',
#    'Club': 'Manchester United',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 18000000.0},
#   {'Id': 357147,
#    'Name': 'Diogo Dalot',
#    'Full Name': 'José Diogo Dalot Teixeira',
#    'Link': 'https://www.transfermarkt.us/diogo-dalot/profil/spieler/357147',
#    'Shirt Number': 20,
#    'DOB': datetime.datetime(1999, 3, 18, 0, 0),
#    'Country': 'Portugal',
#    'Position': 'Right-Back',
#    'Club': 'Manchester United',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 35000000.0},
#   {'Id': 340456,
#    'Name': 'Noussair Mazraoui',
#    'Full Name': 'نصير مزراوي',
#    'Link': 'https://www.transfermarkt.us/noussair-mazraoui/profil/spieler/340456',
#    'Shirt Number': 3,
#    'DOB': datetime.datetime(1997, 11, 14, 0, 0),
#    'Country': 'Morocco',
#    'Position': 'Right-Back',
#    'Club': 'Manchester United',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 30000000.0},
#   {'Id': 476701,
#    'Name': 'Manuel Ugarte',
#    'Full Name': 'Manuel Ugarte Ribeiro',
#    'Link': 'https://www.transfermarkt.us/manuel-ugarte/profil/spieler/476701',
#    'Shirt Number': 25,
#    'DOB': datetime.datetime(2001, 4, 11, 0, 0),
#    'Country': 'Uruguay',
#    'Position': 'Defensive Midfield',
# ...
#    'Shirt Number': 17,
#    'DOB': datetime.datetime(1997, 10, 1, 0, 0),
#    'Country': 'England',
#    'Position': 'Defensive Midfield',
#    'Club': 'Leicester City',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 4500000.0},
#   {'Id': 936842,
#    'Name': 'Michael Golding',
#    'Full Name': 'Michael Heinz Golding',
#    'Link': 'https://www.transfermarkt.us/michael-golding/profil/spieler/936842',
#    'Shirt Number': 34,
#    'DOB': datetime.datetime(2006, 5, 23, 0, 0),
#    'Country': 'England',
#    'Position': 'Central Midfield',
#    'Club': 'Leicester City',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 300000.0},
#   {'Id': 654982,
#    'Name': 'Bilal El Khannouss',
#    'Full Name': 'بلال الخنوس',
#    'Link': 'https://www.transfermarkt.us/bilal-el-khannouss/profil/spieler/654982',
#    'Shirt Number': 11,
#    'DOB': datetime.datetime(2004, 5, 10, 0, 0),
#    'Country': 'Morocco',
#    'Position': 'Attacking Midfield',
#    'Club': 'Leicester City',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 30000000.0},
#   {'Id': 983989,
#    'Name': 'Facundo Buonanotte',
#    'Full Name': 'Facundo Valentín Buonanotte',
#    'Link': 'https://www.transfermarkt.us/facundo-buonanotte/profil/spieler/983989',
#    'Shirt Number': 40,
#    'DOB': datetime.datetime(2004, 12, 23, 0, 0),
#    'Country': 'Argentina',
#    'Position': 'Attacking Midfield',
#    'Club': 'Leicester City',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 18000000.0},
#   {'Id': 340328,
#    'Name': 'Stephy Mavididi',
#    'Full Name': 'Stephy Alvaro Mavididi',
#    'Link': 'https://www.transfermarkt.us/stephy-mavididi/profil/spieler/340328',
#    'Shirt Number': 10,
#    'DOB': datetime.datetime(1998, 5, 31, 0, 0),
#    'Country': 'England',
#    'Position': 'Left Winger',
#    'Club': 'Leicester City',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 11000000.0},
#   {'Id': 864121,
#    'Name': 'Issahaku Fatawu',
#    'Full Name': 'Issahaku Abdul Fatawu',
#    'Link': 'https://www.transfermarkt.us/issahaku-fatawu/profil/spieler/864121',
#    'Shirt Number': 7,
#    'DOB': datetime.datetime(2004, 3, 8, 0, 0),
#    'Country': 'Ghana',
#    'Position': 'Right Winger',
#    'Club': 'Leicester City',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 10000000.0},
#   {'Id': 186186,
#    'Name': 'Bobby De Cordova-Reid',
#    'Full Name': 'Bobby Armani De Cordova-Reid',
#    'Link': 'https://www.transfermarkt.us/bobby-de-cordova-reid/profil/spieler/186186',
#    'Shirt Number': 14,
#    'DOB': datetime.datetime(1993, 2, 2, 0, 0),
#    'Country': 'Jamaica',
#    'Position': 'Right Winger',
#    'Club': 'Leicester City',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 5000000.0},
#   {'Id': 621193,
#    'Name': 'Kasey McAteer',
#    'Full Name': 'Kasey Ian McAteer',
#    'Link': 'https://www.transfermarkt.us/kasey-mcateer/profil/spieler/621193',
#    'Shirt Number': 35,
#    'DOB': datetime.datetime(2001, 11, 22, 0, 0),
#    'Country': 'Ireland',
#    'Position': 'Right Winger',
#    'Club': 'Leicester City',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 900000.0},
#   {'Id': 344152,
#    'Name': 'Odsonne Edouard',
#    'Full Name': 'Odsonne Édouard',
#    'Link': 'https://www.transfermarkt.us/odsonne-edouard/profil/spieler/344152',
#    'Shirt Number': 27,
#    'DOB': datetime.datetime(1998, 1, 16, 0, 0),
#    'Country': 'France',
#    'Position': 'Centre-Forward',
#    'Club': 'Leicester City',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 18000000.0},
#   {'Id': 365172,
#    'Name': 'Patson Daka',
#    'Full Name': 'Patson Daka',
#    'Link': 'https://www.transfermarkt.us/patson-daka/profil/spieler/365172',
#    'Shirt Number': 20,
#    'DOB': datetime.datetime(1998, 10, 9, 0, 0),
#    'Country': 'Zambia',
#    'Position': 'Centre-Forward',
#    'Club': 'Leicester City',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 12000000.0},
#   {'Id': 108354,
#    'Name': 'Jordan Ayew',
#    'Full Name': 'Jordan Pierre Ayew',
#    'Link': 'https://www.transfermarkt.us/jordan-ayew/profil/spieler/108354',
#    'Shirt Number': 18,
#    'DOB': datetime.datetime(1991, 9, 11, 0, 0),
#    'Country': 'Ghana',
#    'Position': 'Centre-Forward',
#    'Club': 'Leicester City',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 4000000.0},
#   {'Id': 197838,
#    'Name': 'Jamie Vardy',
#    'Full Name': 'Jamie Richard Vardy',
#    'Link': 'https://www.transfermarkt.us/jamie-vardy/profil/spieler/197838',
#    'Shirt Number': 9,
#    'DOB': datetime.datetime(1987, 1, 11, 0, 0),
#    'Country': 'England',
#    'Position': 'Centre-Forward',
#    'Club': 'Leicester City',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 1000000.0},
#   {'Id': 371021,
#    'Name': 'Arijanet Muric',
#    'Full Name': 'Arijanet Anan Muriqi',
#    'Link': 'https://www.transfermarkt.us/arijanet-muric/profil/spieler/371021',
#    'Shirt Number': 1,
#    'DOB': datetime.datetime(1998, 11, 7, 0, 0),
#    'Country': 'Kosovo',
#    'Position': 'Goalkeeper',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 7000000.0},
#   {'Id': 208379,
#    'Name': 'Christian Walton',
#    'Full Name': 'Christian Timothy Walton',
#    'Link': 'https://www.transfermarkt.us/christian-walton/profil/spieler/208379',
#    'Shirt Number': 28,
#    'DOB': datetime.datetime(1995, 11, 9, 0, 0),
#    'Country': 'England',
#    'Position': 'Goalkeeper',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 900000.0},
#   {'Id': 621997,
#    'Name': 'Cieran Slicker',
#    'Full Name': 'Cieran Peter Slicker',
#    'Link': 'https://www.transfermarkt.us/cieran-slicker/profil/spieler/621997',
#    'Shirt Number': 13,
#    'DOB': datetime.datetime(2002, 9, 15, 0, 0),
#    'Country': 'Scotland',
#    'Position': 'Goalkeeper',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 300000.0},
#   {'Id': 693095,
#    'Name': 'Jacob Greaves',
#    'Full Name': 'Jacob John Greaves',
#    'Link': 'https://www.transfermarkt.us/jacob-greaves/profil/spieler/693095',
#    'Shirt Number': 24,
#    'DOB': datetime.datetime(2000, 9, 12, 0, 0),
#    'Country': 'England',
#    'Position': 'Centre-Back',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 15000000.0},
#   {'Id': 401320,
#    'Name': "Dara O'Shea",
#    'Full Name': "Dara Joseph O'Shea",
#    'Link': 'https://www.transfermarkt.us/dara-oshea/profil/spieler/401320',
#    'Shirt Number': 26,
#    'DOB': datetime.datetime(1999, 3, 4, 0, 0),
#    'Country': 'Ireland',
#    'Position': 'Centre-Back',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 7000000.0},
#   {'Id': 342046,
#    'Name': 'Axel Tuanzebe',
#    'Full Name': 'Axel Tuanzebe',
#    'Link': 'https://www.transfermarkt.us/axel-tuanzebe/profil/spieler/342046',
#    'Shirt Number': 40,
#    'DOB': datetime.datetime(1997, 11, 14, 0, 0),
#    'Country': 'DR Congo',
#    'Position': 'Centre-Back',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 2200000.0},
#   {'Id': 527425,
#    'Name': 'Luke Woolfenden',
#    'Full Name': 'Luke Matthew Woolfenden',
#    'Link': 'https://www.transfermarkt.us/luke-woolfenden/profil/spieler/527425',
#    'Shirt Number': 6,
#    'DOB': datetime.datetime(1998, 10, 21, 0, 0),
#    'Country': 'England',
#    'Position': 'Centre-Back',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 2000000.0},
#   {'Id': 255788,
#    'Name': 'Cameron Burgess',
#    'Full Name': 'Cameron Robert Burgess',
#    'Link': 'https://www.transfermarkt.us/cameron-burgess/profil/spieler/255788',
#    'Shirt Number': 15,
#    'DOB': datetime.datetime(1995, 10, 21, 0, 0),
#    'Country': 'Australia',
#    'Position': 'Centre-Back',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 1500000.0},
#   {'Id': 596446,
#    'Name': 'Leif Davis',
#    'Full Name': 'Leif Davis',
#    'Link': 'https://www.transfermarkt.us/leif-davis/profil/spieler/596446',
#    'Shirt Number': 3,
#    'DOB': datetime.datetime(1999, 12, 31, 0, 0),
#    'Country': 'England',
#    'Position': 'Left-Back',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 9000000.0},
#   {'Id': 146509,
#    'Name': 'Conor Townsend',
#    'Full Name': 'Conor Stephen Townsend',
#    'Link': 'https://www.transfermarkt.us/conor-townsend/profil/spieler/146509',
#    'Shirt Number': 22,
#    'DOB': datetime.datetime(1993, 3, 4, 0, 0),
#    'Country': 'England',
#    'Position': 'Left-Back',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 1500000.0},
#   {'Id': 468002,
#    'Name': 'Ben Johnson',
#    'Full Name': 'Benjamin Anthony Johnson',
#    'Link': 'https://www.transfermarkt.us/ben-johnson/profil/spieler/468002',
#    'Shirt Number': 18,
#    'DOB': datetime.datetime(2000, 1, 24, 0, 0),
#    'Country': 'England',
#    'Position': 'Right-Back',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 8000000.0},
#   {'Id': 528892,
#    'Name': 'Harry Clarke',
#    'Full Name': 'Harrison Thomas Clarke',
#    'Link': 'https://www.transfermarkt.us/harry-clarke/profil/spieler/528892',
#    'Shirt Number': 2,
#    'DOB': datetime.datetime(2001, 3, 2, 0, 0),
#    'Country': 'England',
#    'Position': 'Right-Back',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 5000000.0},
#   {'Id': 351749,
#    'Name': 'Kalvin Phillips',
#    'Full Name': 'Kalvin Mark Phillips',
#    'Link': 'https://www.transfermarkt.us/kalvin-phillips/profil/spieler/351749',
#    'Shirt Number': 8,
#    'DOB': datetime.datetime(1995, 12, 2, 0, 0),
#    'Country': 'England',
#    'Position': 'Defensive Midfield',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 25000000.0},
#   {'Id': 468066,
#    'Name': 'Jens Cajuste',
#    'Full Name': 'Jens-Lys Michel Cajuste',
#    'Link': 'https://www.transfermarkt.us/jens-cajuste/profil/spieler/468066',
#    'Shirt Number': 12,
#    'DOB': datetime.datetime(1999, 8, 10, 0, 0),
#    'Country': 'Sweden',
#    'Position': 'Defensive Midfield',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 10000000.0},
#   {'Id': 458178,
#    'Name': 'Jack Taylor',
#    'Full Name': 'Jack Henry Philip Taylor',
#    'Link': 'https://www.transfermarkt.us/jack-taylor/profil/spieler/458178',
#    'Shirt Number': 14,
#    'DOB': datetime.datetime(1998, 6, 23, 0, 0),
#    'Country': 'Ireland',
#    'Position': 'Central Midfield',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 1800000.0},
#   {'Id': 123551,
#    'Name': 'Sam Morsy',
#    'Full Name': 'Samy Sayed Mekawy Said Morsy , سامي سيد مكاوي سعيد مرسي',
#    'Link': 'https://www.transfermarkt.us/sam-morsy/profil/spieler/123551',
#    'Shirt Number': 5,
#    'DOB': datetime.datetime(1991, 9, 10, 0, 0),
#    'Country': 'Egypt',
#    'Position': 'Central Midfield',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 900000.0},
#   {'Id': 181687,
#    'Name': 'Massimo Luongo',
#    'Full Name': 'Massimo Corey Luongo',
#    'Link': 'https://www.transfermarkt.us/massimo-luongo/profil/spieler/181687',
#    'Shirt Number': 25,
#    'DOB': datetime.datetime(1992, 9, 25, 0, 0),
#    'Country': 'Australia',
#    'Position': 'Central Midfield',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2025, 6, 30, 0, 0),
#    'Market Value': 500000.0},
#   {'Id': 292139,
#    'Name': 'Sammie Szmodics',
#    'Full Name': 'Samuel Joseph Szmodics',
#    'Link': 'https://www.transfermarkt.us/sammie-szmodics/profil/spieler/292139',
#    'Shirt Number': 23,
#    'DOB': datetime.datetime(1995, 9, 24, 0, 0),
#    'Country': 'Ireland',
#    'Position': 'Attacking Midfield',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 7000000.0},
#   {'Id': 559794,
#    'Name': 'Jack Clarke',
#    'Full Name': 'Jack Raymond Clarke',
#    'Link': 'https://www.transfermarkt.us/jack-clarke/profil/spieler/559794',
#    'Shirt Number': 47,
#    'DOB': datetime.datetime(2000, 11, 23, 0, 0),
#    'Country': 'England',
#    'Position': 'Left Winger',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 15000000.0},
#   {'Id': 344009,
#    'Name': 'Nathan Broadhead',
#    'Full Name': 'Nathan Paul Broadhead',
#    'Link': 'https://www.transfermarkt.us/nathan-broadhead/profil/spieler/344009',
#    'Shirt Number': 33,
#    'DOB': datetime.datetime(1998, 4, 5, 0, 0),
#    'Country': 'Wales',
#    'Position': 'Left Winger',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 5000000.0},
#   {'Id': 392591,
#    'Name': 'Chiedozie Ogbene',
#    'Full Name': 'Chiedozie Somkelechukwu Ogbene',
#    'Link': 'https://www.transfermarkt.us/chiedozie-ogbene/profil/spieler/392591',
#    'Shirt Number': 21,
#    'DOB': datetime.datetime(1997, 5, 1, 0, 0),
#    'Country': 'Ireland',
#    'Position': 'Right Winger',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 8000000.0},
#   {'Id': 741238,
#    'Name': 'Omari Hutchinson',
#    'Full Name': 'Omari Elijah Giraud-Hutchinson',
#    'Link': 'https://www.transfermarkt.us/omari-hutchinson/profil/spieler/741238',
#    'Shirt Number': 20,
#    'DOB': datetime.datetime(2003, 10, 30, 0, 0),
#    'Country': 'England',
#    'Position': 'Right Winger',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 7000000.0},
#   {'Id': 255731,
#    'Name': 'Wes Burns',
#    'Full Name': 'Wesley James Burns',
#    'Link': 'https://www.transfermarkt.us/wes-burns/profil/spieler/255731',
#    'Shirt Number': 7,
#    'DOB': datetime.datetime(1994, 11, 23, 0, 0),
#    'Country': 'Wales',
#    'Position': 'Right Winger',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 1500000.0},
#   {'Id': 349503,
#    'Name': 'Conor Chaplin',
#    'Full Name': 'Conor Mark Chaplin',
#    'Link': 'https://www.transfermarkt.us/conor-chaplin/profil/spieler/349503',
#    'Shirt Number': 10,
#    'DOB': datetime.datetime(1997, 2, 16, 0, 0),
#    'Country': 'England',
#    'Position': 'Second Striker',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2026, 6, 30, 0, 0),
#    'Market Value': 7000000.0},
#   {'Id': 610849,
#    'Name': 'Liam Delap',
#    'Full Name': 'Liam Rory Delap',
#    'Link': 'https://www.transfermarkt.us/liam-delap/profil/spieler/610849',
#    'Shirt Number': 19,
#    'DOB': datetime.datetime(2003, 2, 8, 0, 0),
#    'Country': 'England',
#    'Position': 'Centre-Forward',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2029, 6, 30, 0, 0),
#    'Market Value': 8000000.0},
#   {'Id': 420808,
#    'Name': 'George Hirst',
#    'Full Name': 'George David Eric Hirst',
#    'Link': 'https://www.transfermarkt.us/george-hirst/profil/spieler/420808',
#    'Shirt Number': 27,
#    'DOB': datetime.datetime(1999, 2, 15, 0, 0),
#    'Country': 'England',
#    'Position': 'Centre-Forward',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2027, 6, 30, 0, 0),
#    'Market Value': 4000000.0},
#   {'Id': 610581,
#    'Name': 'Ali Al-Hamadi',
#    'Full Name': 'Ali Ibrahim Karim Ali Al-Hamadi, علي الحمادي',
#    'Link': 'https://www.transfermarkt.us/ali-al-hamadi/profil/spieler/610581',
#    'Shirt Number': 16,
#    'DOB': datetime.datetime(2002, 3, 1, 0, 0),
#    'Country': 'Iraq',
#    'Position': 'Centre-Forward',
#    'Club': 'Ipswich Town',
#    'Contract Expires': datetime.datetime(2028, 6, 30, 0, 0),
#    'Market Value': 1000000.0}]}
